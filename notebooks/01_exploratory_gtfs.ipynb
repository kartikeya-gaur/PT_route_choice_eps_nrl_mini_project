# %% [markdown]
# # Placeholder notebook - see main.py for the runnable pipeline.
# Use this notebook for ad hoc exploration once data/raw/<city>/ is populated.

# %%
import sys
sys.path.insert(0, '..')
from src import config
